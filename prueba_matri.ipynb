# %%
import pandas as pd
datos = 'https://github.com/jhoanmoreno-94/Matriculas_2024/raw/refs/heads/main/matriculas.xlsx'
df = pd.read_excel(datos)
print(df)
# Out:
#        CÓDIGO DE LA INSTITUCIÓN  IES PADRE  \
# 0                          1101       1101
# 1                          1101       1101
# 2                          1101       1101
# 3                          1101       1101
# 4                          1101       1101
# ...                         ...        ...
# 75170                      9936       9936
# 75171                      9936       9936
# 75172                      9936       9936
# 75173                      9938       9938
# 75174                      9938       9938
#
#             INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)   TIPO IES  ID SECTOR IES  \
# 0                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 1                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 2                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 3                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# ...

# %%
df.head(3)
# Out:
#    CÓDIGO DE LA INSTITUCIÓN  IES PADRE  \
# 0                      1101       1101
# 1                      1101       1101
# 2                      1101       1101
#
#   INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)   TIPO IES  ID SECTOR IES  \
# 0        UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 1        UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 2        UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
#
#   SECTOR IES  ID CARÁCTER IES CARÁCTER IES  CÓDIGO DEL DEPARTAMENTO (IES)  \
# 0    Oficial                4  Universidad                             11
# 1    Oficial                4  Universidad                             11
# 2    Oficial                4  Universidad                             11
#
#   DEPARTAMENTO DE DOMICILIO DE LA IES  ...       DESC CINE CAMPO DETALLADO  \
# 0                        Bogotá, D.C.  ...  Producción agrícola y ganadera
# 1                        Bogotá, D.C.  ...  Producción agrícola y ganadera
# ...

# %%
df.tail(3)
# Out:
#        CÓDIGO DE LA INSTITUCIÓN  IES PADRE  \
# 75172                      9936       9936
# 75173                      9938       9938
# 75174                      9938       9938
#
#             INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)   TIPO IES  ID SECTOR IES  \
# 75172  CORPORACIÓN UNIVERSITARIA AUTÓNOMA DEL NORTE  Principal              2
# 75173                  UNIVERSITARIA DEL CHICAMOCHA  Principal              2
# 75174                  UNIVERSITARIA DEL CHICAMOCHA  Principal              2
#
#       SECTOR IES  ID CARÁCTER IES  \
# 75172    Privado                3
# 75173    Privado                3
# 75174    Privado                3
#
#                                         CARÁCTER IES  \
# 75172  Institución Universitaria/Escuela Tecnológica
# 75173  Institución Universitaria/Escuela Tecnológica
# 75174  Institución Universitaria/Escuela Tecnológica
#
#        CÓDIGO DEL DEPARTAMENTO (IES) DEPARTAMENTO DE DOMICILIO DE LA IES  ...  \
# ...

# %%
df.dtypes
# Out:
# CÓDIGO DE LA INSTITUCIÓN                   int64
# IES PADRE                                  int64
# INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)      str
# TIPO IES                                     str
# ID SECTOR IES                              int64
# SECTOR IES                                   str
# ID CARÁCTER IES                            int64
# CARÁCTER IES                                 str
# CÓDIGO DEL DEPARTAMENTO (IES)              int64
# DEPARTAMENTO DE DOMICILIO DE LA IES          str
# CÓDIGO DEL MUNICIPIO IES                   int64
# MUNICIPIO DE DOMICILIO DE LA IES             str
# IES ACREDITADA                               str
# CÓDIGO SNIES DEL PROGRAMA                  int64
# PROGRAMA ACADÉMICO                           str
# PROGRAMA ACREDITADO                          str
# ID NIVEL ACADÉMICO                         int64
# NIVEL ACADÉMICO                              str
# ID NIVEL DE FORMACIÓN                      int64
# ...

# %%
df.shape
# Out:
# (75175, 41)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75175 entries, 0 to 75174
# Data columns (total 41 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CÓDIGO DE LA INSTITUCIÓN                 75175 non-null  int64
#  1   IES PADRE                                75175 non-null  int64
#  2   INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)  75175 non-null  str
#  3   TIPO IES                                 75175 non-null  str
#  4   ID SECTOR IES                            75175 non-null  int64
#  5   SECTOR IES                               75175 non-null  str
#  6   ID CARÁCTER IES                          75175 non-null  int64
#  7   CARÁCTER IES                             75175 non-null  str
#  8   CÓDIGO DEL DEPARTAMENTO (IES)            75175 non-null  int64
#  9   DEPARTAMENTO DE DOMICILIO DE LA IES      75175 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# CÓDIGO DE LA INSTITUCIÓN                   0
# IES PADRE                                  0
# INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)    0
# TIPO IES                                   0
# ID SECTOR IES                              0
# SECTOR IES                                 0
# ID CARÁCTER IES                            0
# CARÁCTER IES                               0
# CÓDIGO DEL DEPARTAMENTO (IES)              0
# DEPARTAMENTO DE DOMICILIO DE LA IES        0
# CÓDIGO DEL MUNICIPIO IES                   0
# MUNICIPIO DE DOMICILIO DE LA IES           0
# IES ACREDITADA                             0
# CÓDIGO SNIES DEL PROGRAMA                  0
# PROGRAMA ACADÉMICO                         0
# PROGRAMA ACREDITADO                        0
# ID NIVEL ACADÉMICO                         0
# NIVEL ACADÉMICO                            0
# ID NIVEL DE FORMACIÓN                      0
# NIVEL DE FORMACIÓN                         0
# ID MODALIDAD                               0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Eliminar columnas innecesarias
columna = ['CÓDIGO DE LA INSTITUCIÓN','IES PADRE', 'ID SECTOR IES','ID CARÁCTER IES','CÓDIGO DEL DEPARTAMENTO (IES)','CÓDIGO DEL MUNICIPIO IES',
           'ID NIVEL ACADÉMICO','ID NIVEL DE FORMACIÓN','ID MODALIDAD','ID ÁREA','ID NÚCLEO','ID CINE CAMPO AMPLIO','ID CINE CAMPO ESPECIFICO','ID CINE CAMPO DETALLADO',
           'CÓDIGO DEL DEPARTAMENTO (PROGRAMA)','CÓDIGO DEL MUNICIPIO (PROGRAMA)','ID SEXO'
          ]
df = df.drop(columns=columna)

# %%
df.duplicated().sum() #se volvio a llamar el metodo porque encontré que si quitaba el CÓDIGO DEL MUNICIPIO IES aparecian duplicados
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)', 'TIPO IES', 'SECTOR IES',
#        'CARÁCTER IES', 'DEPARTAMENTO DE DOMICILIO DE LA IES',
#        'MUNICIPIO DE DOMICILIO DE LA IES', 'IES ACREDITADA',
#        'CÓDIGO SNIES DEL PROGRAMA', 'PROGRAMA ACADÉMICO',
#        'PROGRAMA ACREDITADO', 'NIVEL ACADÉMICO', 'NIVEL DE FORMACIÓN',
#        'MODALIDAD', 'ÁREA DE CONOCIMIENTO',
#        'NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)', 'DESC CINE CAMPO AMPLIO',
#        'DESC CINE CAMPO ESPECIFICO', 'DESC CINE CAMPO DETALLADO',
#        'DEPARTAMENTO DE OFERTA DEL PROGRAMA',
#        'MUNICIPIO DE OFERTA DEL PROGRAMA', 'SEXO', 'AÑO', 'SEMESTRE',
#        'MATRICULADOS'],
#       dtype='str')

# %%
df.shape
# Out:
# (75175, 24)

# %%
df.columns = df.columns.str.replace(" ", "_").str.title()
df.columns
# Out:
# Index(['Institución_De_Educación_Superior_(Ies)', 'Tipo_Ies', 'Sector_Ies',
#        'Carácter_Ies', 'Departamento_De_Domicilio_De_La_Ies',
#        'Municipio_De_Domicilio_De_La_Ies', 'Ies_Acreditada',
#        'Código_Snies_Del_Programa', 'Programa_Académico',
#        'Programa_Acreditado', 'Nivel_Académico', 'Nivel_De_Formación',
#        'Modalidad', 'Área_De_Conocimiento',
#        'Núcleo_Básico_Del_Conocimiento_(Nbc)', 'Desc_Cine_Campo_Amplio',
#        'Desc_Cine_Campo_Especifico', 'Desc_Cine_Campo_Detallado',
#        'Departamento_De_Oferta_Del_Programa',
#        'Municipio_De_Oferta_Del_Programa', 'Sexo', 'Año', 'Semestre',
#        'Matriculados'],
#       dtype='str')

# %%
df['Institución_De_Educación_Superior_(Ies)'].unique()
# Out:
# <StringArray>
# [                                                       'UNIVERSIDAD NACIONAL DE COLOMBIA',
#                                                          'UNIVERSIDAD PEDAGOGICA NACIONAL',
#                                  'UNIVERSIDAD PEDAGOGICA Y TECNOLOGICA DE COLOMBIA - UPTC',
#                                                                    'UNIVERSIDAD DEL CAUCA',
#                                                 'UNIVERSIDAD TECNOLOGICA DE PEREIRA - UTP',
#                                                                    'UNIVERSIDAD DE CALDAS',
#                                                                   'UNIVERSIDAD DE CORDOBA',
#                                                                'UNIVERSIDAD SURCOLOMBIANA',
#                                                               'UNIVERSIDAD DE LA AMAZONIA',
#                                                        'UNIVERSIDAD MILITAR-NUEVA GRANADA',
#  ...
# ...

# %%
df['Departamento_De_Oferta_Del_Programa'].unique()
# Out:
# <StringArray>
# [                                            'Bogotá, D.C.',
#                                                 'Antioquia',
#                                                    'Caldas',
#                                           'Valle del Cauca',
#                                                    'Boyacá',
#                                                  'Casanare',
#                                                     'Cauca',
#                                                    'Nariño',
#                                                 'Risaralda',
#                                                'La Guajira',
#                                                     'Huila',
#                                                   'Córdoba',
#                                                   'Caquetá',
#                                                  'Guaviare',
#                                                  'Amazonas',
# ...

# %%
df['Programa_Académico'].unique()
# Out:
# <StringArray>
# [                                                                     'INGENIERIA AGRONOMICA',
#                                                                       'NUTRICION Y DIETETICA',
#                                                          'MAESTRIA EN INGENIERIA - GEOTECNIA',
#                                                        'MAESTRIA EN INGENIERIA - ESTRUCTURAS',
#                                                         'MAESTRÍA EN CONTABILIDAD Y FINANZAS',
#                                                             'MAESTRÍA EN EDUCACIÓN ARTÍSTICA',
#                                             'MAESTRIA EN INGENIERIA - INGENIERIA ELECTRONICA',
#                                                                     'MAESTRÍA EN MUSICOLOGÍA',
#                                                          'DOCTORADO EN CIENCIAS - BIOQUIMICA',
#                                                                  'MAESTRÍA EN BIOINFORMÁTICA',
#  ...
# ...

# %%
df['Modalidad'].unique()
# Out:
# <StringArray>
# [                  'Presencial',                  'A distancia',
#            'Presencial-Virtual',                      'Virtual',
#  'Híbrida (Presencial-Virtual)',                         'Dual',
#                  'Virtual-Dual',       'Presencial-A distancia',
#           'Virtual-A distancia',              'Presencial-Dual']
# Length: 10, dtype: str

# %%
df.loc[df['Departamento_De_Oferta_Del_Programa']== 'Antioquia', ['Institución_De_Educación_Superior_(Ies)','Programa_Académico','Modalidad']]
# Out:
#                  Institución_De_Educación_Superior_(Ies)  \
# 1023                    UNIVERSIDAD NACIONAL DE COLOMBIA
# 1024                    UNIVERSIDAD NACIONAL DE COLOMBIA
# 1025                    UNIVERSIDAD NACIONAL DE COLOMBIA
# 1026                    UNIVERSIDAD NACIONAL DE COLOMBIA
# 1027                    UNIVERSIDAD NACIONAL DE COLOMBIA
# ...                                                  ...
# 74477  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...
# 74478  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...
# 74773  UNIVERSIDAD AUTÓNOMA INDÍGENA INTERCULTURAL - ...
# 74774  UNIVERSIDAD AUTÓNOMA INDÍGENA INTERCULTURAL - ...
# 74775  UNIVERSIDAD AUTÓNOMA INDÍGENA INTERCULTURAL - ...
#
#                                       Programa_Académico   Modalidad
# 1023       MAESTRIA EN INGENIERIA - INGENIERIA ELECTRICA  Presencial
# 1024       MAESTRIA EN INGENIERIA - INGENIERIA ELECTRICA  Presencial
# 1025       MAESTRIA EN INGENIERIA - INGENIERIA ELECTRICA  Presencial
# ...

# %%
df[(df['Departamento_De_Oferta_Del_Programa']=='Valle del Cauca') & (df['Modalidad']=='Virtual')]
# Out:
#                  Institución_De_Educación_Superior_(Ies)   Tipo_Ies  \
# 8760                               UNIVERSIDAD DEL VALLE  Principal
# 8761                               UNIVERSIDAD DEL VALLE  Principal
# 8762                               UNIVERSIDAD DEL VALLE  Principal
# 8763                               UNIVERSIDAD DEL VALLE  Principal
# 8789                               UNIVERSIDAD DEL VALLE  Principal
# ...                                                  ...        ...
# 61416     INSTITUCION UNIVERSITARIA ANTONIO JOSE CAMACHO  Principal
# 64671  CORPORACION REGIONAL DE EDUCACION SUPERIOR-CRE...  Principal
# 64672  CORPORACION REGIONAL DE EDUCACION SUPERIOR-CRE...  Principal
# 64673  CORPORACION REGIONAL DE EDUCACION SUPERIOR-CRE...  Principal
# 64674  CORPORACION REGIONAL DE EDUCACION SUPERIOR-CRE...  Principal
#
#       Sector_Ies                                   Carácter_Ies  \
# 8760     Oficial                                    Universidad
# ...

# %%
df[(df['Departamento_De_Domicilio_De_La_Ies']== 'Antioquia')| (df['Municipio_De_Domicilio_De_La_Ies']== 'Bello')]
# Out:
#                  Institución_De_Educación_Superior_(Ies)   Tipo_Ies  \
# 1023                    UNIVERSIDAD NACIONAL DE COLOMBIA  Seccional
# 1024                    UNIVERSIDAD NACIONAL DE COLOMBIA  Seccional
# 1025                    UNIVERSIDAD NACIONAL DE COLOMBIA  Seccional
# 1026                    UNIVERSIDAD NACIONAL DE COLOMBIA  Seccional
# 1027                    UNIVERSIDAD NACIONAL DE COLOMBIA  Seccional
# ...                                                  ...        ...
# 74474  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  Principal
# 74475  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  Principal
# 74476  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  Principal
# 74477  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  Principal
# 74478  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  Principal
#
#       Sector_Ies                                   Carácter_Ies  \
# 1023     Oficial                                    Universidad
# ...

# %%
can_instituciones_program = df.groupby('Institución_De_Educación_Superior_(Ies)')['Programa_Académico'].count().sort_values(ascending=False)
print(can_instituciones_program)
# Out:
# Institución_De_Educación_Superior_(Ies)
# UNIVERSIDAD NACIONAL ABIERTA Y A DISTANCIA UNAD                  14984
# SERVICIO NACIONAL DE APRENDIZAJE-SENA-                            6585
# UNIVERSIDAD SANTO TOMAS                                           1818
# UNIVERSIDAD NACIONAL DE COLOMBIA                                  1763
# UNIVERSIDAD DE ANTIOQUIA                                          1729
#                                                                  ...
# ESCUELA INTERNACIONAL DE ESTUDIOS SUPERIORES - INTER                 4
# CORPORACIÓN TECNOLÓGICA DE EDUCACIÓN SUPERIOR SAPIENZA - CTES        4
# UNIVERSITARIA DEL CHICAMOCHA                                         2
# UNIDAD TECNOLÓGICA DEL MAGDALENA MEDIO - UTEM -                      2
# CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE -IAFIC-                2
# Name: Programa_Académico, Length: 277, dtype: int64

# %%
inf_departamentos = df.groupby('Departamento_De_Oferta_Del_Programa').agg({'Matriculados': ['sum', 'mean', 'max', 'min']})
print(inf_departamentos)
# Out:
#                                                    Matriculados              \
#                                                             sum        mean
# Departamento_De_Oferta_Del_Programa
# Amazonas                                                   1663    8.072816
# Antioquia                                                613829   65.148482
# Arauca                                                     2604   19.147059
# Archipiélago de San Andrés, Providencia y Santa...         1815   25.928571
# Atlántico                                                277710   73.448823
# Bogotá, D.C.                                            1686591  106.248646
# Bolívar                                                  161269   71.516186
# Boyacá                                                   147791   41.247837
# Caldas                                                    95516   41.082151
# Caquetá                                                   26782   38.150997
# ...

# %%
df['Departamento_De_Oferta_Del_Programa'].unique()
# Out:
# <StringArray>
# [                                            'Bogotá, D.C.',
#                                                 'Antioquia',
#                                                    'Caldas',
#                                           'Valle del Cauca',
#                                                    'Boyacá',
#                                                  'Casanare',
#                                                     'Cauca',
#                                                    'Nariño',
#                                                 'Risaralda',
#                                                'La Guajira',
#                                                     'Huila',
#                                                   'Córdoba',
#                                                   'Caquetá',
#                                                  'Guaviare',
#                                                  'Amazonas',
# ...

# %%
#uni_depar_ant = df.loc[df['Departamento_De_Oferta_Del_Programa']== 'Antioquia', ['Institución_De_Educación_Superior_(Ies)','Programa_Académico','Modalidad','Matriculados']]
#uni_depar_ant.to_csv('uni_depar_ant.csv', index=False)

# %%
#uni_depar_dc = df.loc[df['Departamento_De_Oferta_Del_Programa']== 'Bogotá, D.C.', ['Institución_De_Educación_Superior_(Ies)','Programa_Académico','Modalidad','Matriculados']]
#uni_depar_dc.to_csv('uni_depar_dc.csv', index=False)

# %%
#unis_ant = 'https://github.com/jhoanmoreno-94/Matriculas_2024/raw/refs/heads/main/uni_depar_ant.csv'
#df_uni_ant = pd.read_csv(unis_ant)
#df_uni_ant.head(3)

# %%
#unis_dc = 'https://github.com/jhoanmoreno-94/Matriculas_2024/raw/refs/heads/main/uni_depar_dc.csv'
#df_uni_dc = pd.read_csv(unis_dc)
#df_uni_dc.head(3)

# %%
#uni_juntas =pd.concat([df_uni_ant,df_uni_dc], axis=0, ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75175 entries, 0 to 75174
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Institución_De_Educación_Superior_(Ies)  75175 non-null  str
#  1   Tipo_Ies                                 75175 non-null  str
#  2   Sector_Ies                               75175 non-null  str
#  3   Carácter_Ies                             75175 non-null  str
#  4   Departamento_De_Domicilio_De_La_Ies      75175 non-null  str
#  5   Municipio_De_Domicilio_De_La_Ies         75175 non-null  str
#  6   Ies_Acreditada                           75175 non-null  str
#  7   Código_Snies_Del_Programa                75175 non-null  int64
#  8   Programa_Académico                       75175 non-null  str
#  9   Programa_Acreditado                      75175 non-null  str
#  10  Nivel_Académico                          75175 non-null  str
# ...

# %%
df['Institución_De_Educación_Superior_(Ies)'].nunique()
# Out:
# 277

# %%
df['Departamento_De_Oferta_Del_Programa'].nunique()
# Out:
# 33

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
barras = plt.bar(df['Departamento_De_Oferta_Del_Programa'].value_counts().index, df['Departamento_De_Oferta_Del_Programa'].value_counts().values, 
        label='Departamento', color='green')
plt.title('Departamentos')
plt.xticks(rotation=90)
plt.bar_label(barras, rotation=90, padding=3)
#plt.tight_layout()
plt.show()

# %%
cantidad_departamentos = df['Departamento_De_Oferta_Del_Programa'].value_counts()
print(cantidad_departamentos)
# Out:
# Departamento_De_Oferta_Del_Programa
# Bogotá, D.C.                                                15874
# Antioquia                                                    9422
# Valle del Cauca                                              5929
# Santander                                                    4025
# Atlántico                                                    3781
# Cundinamarca                                                 3620
# Boyacá                                                       3583
# Norte de Santander                                           2343
# Cauca                                                        2330
# Caldas                                                       2325
# Bolívar                                                      2255
# Tolima                                                       2119
# Huila                                                        2074
# Nariño                                                       1852
# ...

# %%
cant_adm_depar =df.groupby('Departamento_De_Oferta_Del_Programa')['Matriculados'].count().sort_values(ascending=False)
print(cant_adm_depar)
# Out:
# Departamento_De_Oferta_Del_Programa
# Bogotá, D.C.                                                15874
# Antioquia                                                    9422
# Valle del Cauca                                              5929
# Santander                                                    4025
# Atlántico                                                    3781
# Cundinamarca                                                 3620
# Boyacá                                                       3583
# Norte de Santander                                           2343
# Cauca                                                        2330
# Caldas                                                       2325
# Bolívar                                                      2255
# Tolima                                                       2119
# Huila                                                        2074
# Nariño                                                       1852
# ...

# %%
cant_adm_depar =df.groupby('Departamento_De_Oferta_Del_Programa')['Matriculados'].count().sort_values(ascending=False)
plt.figure(figsize=(10,6))
ax = cant_adm_depar.plot(kind='bar')
plt.title('Cantidad de matriculados')
plt.xlabel('Departamentos')
plt.ylabel('Cantidad de matriculados')
for container in ax.containers:
    ax.bar_label(container, rotation=90, padding=3)
#plt.tight_layout()
plt.show()
