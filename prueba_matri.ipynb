# %%
import pandas as pd
datos = 'https://github.com/jhoanmoreno-94/Matriculas_2024/raw/refs/heads/main/matriculas.xlsx'
df = pd.read_excel(datos)
print(df)
# Out:
#        CÓDIGO DE LA INSTITUCIÓN  IES PADRE  \
# 0                          1101       1101
# 1                          1101       1101
# 2                          1101       1101
# 3                          1101       1101
# 4                          1101       1101
# ...                         ...        ...
# 75170                      9936       9936
# 75171                      9936       9936
# 75172                      9936       9936
# 75173                      9938       9938
# 75174                      9938       9938
#
#             INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)   TIPO IES  ID SECTOR IES  \
# 0                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 1                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 2                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 3                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 4                  UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# ...                                             ...        ...            ...
# 75170  CORPORACIÓN UNIVERSITARIA AUTÓNOMA DEL NORTE  Principal              2
# 75171  CORPORACIÓN UNIVERSITARIA AUTÓNOMA DEL NORTE  Principal              2
# 75172  CORPORACIÓN UNIVERSITARIA AUTÓNOMA DEL NORTE  Principal              2
# 75173                  UNIVERSITARIA DEL CHICAMOCHA  Principal              2
# 75174                  UNIVERSITARIA DEL CHICAMOCHA  Principal              2
#
#       SECTOR IES  ID CARÁCTER IES  \
# 0        Oficial                4
# 1        Oficial                4
# 2        Oficial                4
# 3        Oficial                4
# 4        Oficial                4
# ...          ...              ...
# 75170    Privado                3
# 75171    Privado                3
# 75172    Privado                3
# 75173    Privado                3
# 75174    Privado                3
#
#                                         CARÁCTER IES  \
# 0                                        Universidad
# 1                                        Universidad
# 2                                        Universidad
# 3                                        Universidad
# 4                                        Universidad
# ...                                              ...
# 75170  Institución Universitaria/Escuela Tecnológica
# 75171  Institución Universitaria/Escuela Tecnológica
# 75172  Institución Universitaria/Escuela Tecnológica
# 75173  Institución Universitaria/Escuela Tecnológica
# 75174  Institución Universitaria/Escuela Tecnológica
#
#        CÓDIGO DEL DEPARTAMENTO (IES) DEPARTAMENTO DE DOMICILIO DE LA IES  ...  \
# 0                                 11                        Bogotá, D.C.  ...
# 1                                 11                        Bogotá, D.C.  ...
# 2                                 11                        Bogotá, D.C.  ...
# 3                                 11                        Bogotá, D.C.  ...
# 4                                 11                        Bogotá, D.C.  ...
# ...                              ...                                 ...  ...
# 75170                             54                  Norte de Santander  ...
# 75171                             54                  Norte de Santander  ...
# 75172                             54                  Norte de Santander  ...
# 75173                             68                           Santander  ...
# 75174                             68                           Santander  ...
#
#                                DESC CINE CAMPO DETALLADO  \
# 0                         Producción agrícola y ganadera
# 1                         Producción agrícola y ganadera
# 2                         Producción agrícola y ganadera
# 3                         Producción agrícola y ganadera
# 4      Fisioterapia, Fonoaudiología, Terapia ocupacio...
# ...                                                  ...
# 75170                                            Derecho
# 75171                                         Psicología
# 75172                                         Psicología
# 75173   Hotelería, restaurantes y servicios de banquetes
# 75174   Hotelería, restaurantes y servicios de banquetes
#
#       CÓDIGO DEL DEPARTAMENTO (PROGRAMA) DEPARTAMENTO DE OFERTA DEL PROGRAMA  \
# 0                                     11                        Bogotá, D.C.
# 1                                     11                        Bogotá, D.C.
# 2                                     11                        Bogotá, D.C.
# 3                                     11                        Bogotá, D.C.
# 4                                     11                        Bogotá, D.C.
# ...                                  ...                                 ...
# 75170                                 54                  Norte de Santander
# 75171                                 54                  Norte de Santander
# 75172                                 54                  Norte de Santander
# 75173                                 85                            Casanare
# 75174                                 85                            Casanare
#
#        CÓDIGO DEL MUNICIPIO (PROGRAMA) MUNICIPIO DE OFERTA DEL PROGRAMA  \
# 0                                11001                     Bogotá, D.C.
# 1                                11001                     Bogotá, D.C.
# 2                                11001                     Bogotá, D.C.
# 3                                11001                     Bogotá, D.C.
# 4                                11001                     Bogotá, D.C.
# ...                                ...                              ...
# 75170                            54001               San José de Cúcuta
# 75171                            54001               San José de Cúcuta
# 75172                            54001               San José de Cúcuta
# 75173                            85001                            Yopal
# 75174                            85001                            Yopal
#
#       ID SEXO       SEXO   AÑO  SEMESTRE MATRICULADOS
# 0           1  Masculino  2024         1          500
# 1           1  Masculino  2024         2          497
# 2           2   Femenino  2024         1          337
# 3           2   Femenino  2024         2          331
# 4           1  Masculino  2024         1          113
# ...       ...        ...   ...       ...          ...
# 75170       2   Femenino  2024         2            2
# 75171       1  Masculino  2024         2            3
# 75172       2   Femenino  2024         2           13
# 75173       1  Masculino  2024         2           27
# 75174       2   Femenino  2024         2           25
#
# [75175 rows x 41 columns]

# %%
df.head(3)
# Out:
#    CÓDIGO DE LA INSTITUCIÓN  IES PADRE  \
# 0                      1101       1101
# 1                      1101       1101
# 2                      1101       1101
#
#   INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)   TIPO IES  ID SECTOR IES  \
# 0        UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 1        UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
# 2        UNIVERSIDAD NACIONAL DE COLOMBIA  Principal              1
#
#   SECTOR IES  ID CARÁCTER IES CARÁCTER IES  CÓDIGO DEL DEPARTAMENTO (IES)  \
# 0    Oficial                4  Universidad                             11
# 1    Oficial                4  Universidad                             11
# 2    Oficial                4  Universidad                             11
#
#   DEPARTAMENTO DE DOMICILIO DE LA IES  ...       DESC CINE CAMPO DETALLADO  \
# 0                        Bogotá, D.C.  ...  Producción agrícola y ganadera
# 1                        Bogotá, D.C.  ...  Producción agrícola y ganadera
# 2                        Bogotá, D.C.  ...  Producción agrícola y ganadera
#
#   CÓDIGO DEL DEPARTAMENTO (PROGRAMA) DEPARTAMENTO DE OFERTA DEL PROGRAMA  \
# 0                                 11                        Bogotá, D.C.
# 1                                 11                        Bogotá, D.C.
# 2                                 11                        Bogotá, D.C.
#
#    CÓDIGO DEL MUNICIPIO (PROGRAMA) MUNICIPIO DE OFERTA DEL PROGRAMA ID SEXO  \
# 0                            11001                     Bogotá, D.C.       1
# 1                            11001                     Bogotá, D.C.       1
# 2                            11001                     Bogotá, D.C.       2
#
#         SEXO   AÑO  SEMESTRE MATRICULADOS
# 0  Masculino  2024         1          500
# 1  Masculino  2024         2          497
# 2   Femenino  2024         1          337
#
# [3 rows x 41 columns]

# %%
df.tail(3)
# Out:
#        CÓDIGO DE LA INSTITUCIÓN  IES PADRE  \
# 75172                      9936       9936
# 75173                      9938       9938
# 75174                      9938       9938
#
#             INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)   TIPO IES  ID SECTOR IES  \
# 75172  CORPORACIÓN UNIVERSITARIA AUTÓNOMA DEL NORTE  Principal              2
# 75173                  UNIVERSITARIA DEL CHICAMOCHA  Principal              2
# 75174                  UNIVERSITARIA DEL CHICAMOCHA  Principal              2
#
#       SECTOR IES  ID CARÁCTER IES  \
# 75172    Privado                3
# 75173    Privado                3
# 75174    Privado                3
#
#                                         CARÁCTER IES  \
# 75172  Institución Universitaria/Escuela Tecnológica
# 75173  Institución Universitaria/Escuela Tecnológica
# 75174  Institución Universitaria/Escuela Tecnológica
#
#        CÓDIGO DEL DEPARTAMENTO (IES) DEPARTAMENTO DE DOMICILIO DE LA IES  ...  \
# 75172                             54                  Norte de Santander  ...
# 75173                             68                           Santander  ...
# 75174                             68                           Santander  ...
#
#                               DESC CINE CAMPO DETALLADO  \
# 75172                                        Psicología
# 75173  Hotelería, restaurantes y servicios de banquetes
# 75174  Hotelería, restaurantes y servicios de banquetes
#
#       CÓDIGO DEL DEPARTAMENTO (PROGRAMA) DEPARTAMENTO DE OFERTA DEL PROGRAMA  \
# 75172                                 54                  Norte de Santander
# 75173                                 85                            Casanare
# 75174                                 85                            Casanare
#
#        CÓDIGO DEL MUNICIPIO (PROGRAMA) MUNICIPIO DE OFERTA DEL PROGRAMA  \
# 75172                            54001               San José de Cúcuta
# 75173                            85001                            Yopal
# 75174                            85001                            Yopal
#
#       ID SEXO       SEXO   AÑO  SEMESTRE MATRICULADOS
# 75172       2   Femenino  2024         2           13
# 75173       1  Masculino  2024         2           27
# 75174       2   Femenino  2024         2           25
#
# [3 rows x 41 columns]

# %%
df.dtypes
# Out:
# CÓDIGO DE LA INSTITUCIÓN                    int64
# IES PADRE                                   int64
# INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)    object
# TIPO IES                                   object
# ID SECTOR IES                               int64
# SECTOR IES                                 object
# ID CARÁCTER IES                             int64
# CARÁCTER IES                               object
# CÓDIGO DEL DEPARTAMENTO (IES)               int64
# DEPARTAMENTO DE DOMICILIO DE LA IES        object
# CÓDIGO DEL MUNICIPIO IES                    int64
# MUNICIPIO DE DOMICILIO DE LA IES           object
# IES ACREDITADA                             object
# CÓDIGO SNIES DEL PROGRAMA                   int64
# PROGRAMA ACADÉMICO                         object
# PROGRAMA ACREDITADO                        object
# ID NIVEL ACADÉMICO                          int64
# NIVEL ACADÉMICO                            object
# ID NIVEL DE FORMACIÓN                       int64
# NIVEL DE FORMACIÓN                         object
# ID MODALIDAD                                int64
# MODALIDAD                                  object
# ID ÁREA                                     int64
# ÁREA DE CONOCIMIENTO                       object
# ID NÚCLEO                                   int64
# NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)       object
# ID CINE CAMPO AMPLIO                        int64
# DESC CINE CAMPO AMPLIO                     object
# ID CINE CAMPO ESPECIFICO                    int64
# DESC CINE CAMPO ESPECIFICO                 object
# ID CINE CAMPO DETALLADO                     int64
# DESC CINE CAMPO DETALLADO                  object
# CÓDIGO DEL DEPARTAMENTO (PROGRAMA)          int64
# DEPARTAMENTO DE OFERTA DEL PROGRAMA        object
# CÓDIGO DEL MUNICIPIO (PROGRAMA)             int64
# MUNICIPIO DE OFERTA DEL PROGRAMA           object
# ID SEXO                                     int64
# SEXO                                       object
# AÑO                                         int64
# SEMESTRE                                    int64
# MATRICULADOS                                int64
# dtype: object

# %%
df.shape
# Out:
# (75175, 41)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75175 entries, 0 to 75174
# Data columns (total 41 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CÓDIGO DE LA INSTITUCIÓN                 75175 non-null  int64
#  1   IES PADRE                                75175 non-null  int64
#  2   INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)  75175 non-null  object
#  3   TIPO IES                                 75175 non-null  object
#  4   ID SECTOR IES                            75175 non-null  int64
#  5   SECTOR IES                               75175 non-null  object
#  6   ID CARÁCTER IES                          75175 non-null  int64
#  7   CARÁCTER IES                             75175 non-null  object
#  8   CÓDIGO DEL DEPARTAMENTO (IES)            75175 non-null  int64
#  9   DEPARTAMENTO DE DOMICILIO DE LA IES      75175 non-null  object
#  10  CÓDIGO DEL MUNICIPIO IES                 75175 non-null  int64
#  11  MUNICIPIO DE DOMICILIO DE LA IES         75175 non-null  object
#  12  IES ACREDITADA                           75175 non-null  object
#  13  CÓDIGO SNIES DEL PROGRAMA                75175 non-null  int64
#  14  PROGRAMA ACADÉMICO                       75175 non-null  object
#  15  PROGRAMA ACREDITADO                      75175 non-null  object
#  16  ID NIVEL ACADÉMICO                       75175 non-null  int64
#  17  NIVEL ACADÉMICO                          75175 non-null  object
#  18  ID NIVEL DE FORMACIÓN                    75175 non-null  int64
#  19  NIVEL DE FORMACIÓN                       75175 non-null  object
#  20  ID MODALIDAD                             75175 non-null  int64
#  21  MODALIDAD                                75175 non-null  object
#  22  ID ÁREA                                  75175 non-null  int64
#  23  ÁREA DE CONOCIMIENTO                     75175 non-null  object
#  24  ID NÚCLEO                                75175 non-null  int64
#  25  NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)     75175 non-null  object
#  26  ID CINE CAMPO AMPLIO                     75175 non-null  int64
#  27  DESC CINE CAMPO AMPLIO                   75175 non-null  object
#  28  ID CINE CAMPO ESPECIFICO                 75175 non-null  int64
#  29  DESC CINE CAMPO ESPECIFICO               75175 non-null  object
#  30  ID CINE CAMPO DETALLADO                  75175 non-null  int64
#  31  DESC CINE CAMPO DETALLADO                75175 non-null  object
#  32  CÓDIGO DEL DEPARTAMENTO (PROGRAMA)       75175 non-null  int64
#  33  DEPARTAMENTO DE OFERTA DEL PROGRAMA      75175 non-null  object
#  34  CÓDIGO DEL MUNICIPIO (PROGRAMA)          75175 non-null  int64
#  35  MUNICIPIO DE OFERTA DEL PROGRAMA         75175 non-null  object
#  36  ID SEXO                                  75175 non-null  int64
#  37  SEXO                                     75175 non-null  object
#  38  AÑO                                      75175 non-null  int64
#  39  SEMESTRE                                 75175 non-null  int64
#  40  MATRICULADOS                             75175 non-null  int64
# dtypes: int64(21), object(20)
# memory usage: 23.5+ MB

# %%
df.isnull().sum()
# Out:
# CÓDIGO DE LA INSTITUCIÓN                   0
# IES PADRE                                  0
# INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)    0
# TIPO IES                                   0
# ID SECTOR IES                              0
# SECTOR IES                                 0
# ID CARÁCTER IES                            0
# CARÁCTER IES                               0
# CÓDIGO DEL DEPARTAMENTO (IES)              0
# DEPARTAMENTO DE DOMICILIO DE LA IES        0
# CÓDIGO DEL MUNICIPIO IES                   0
# MUNICIPIO DE DOMICILIO DE LA IES           0
# IES ACREDITADA                             0
# CÓDIGO SNIES DEL PROGRAMA                  0
# PROGRAMA ACADÉMICO                         0
# PROGRAMA ACREDITADO                        0
# ID NIVEL ACADÉMICO                         0
# NIVEL ACADÉMICO                            0
# ID NIVEL DE FORMACIÓN                      0
# NIVEL DE FORMACIÓN                         0
# ID MODALIDAD                               0
# MODALIDAD                                  0
# ID ÁREA                                    0
# ÁREA DE CONOCIMIENTO                       0
# ID NÚCLEO                                  0
# NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)       0
# ID CINE CAMPO AMPLIO                       0
# DESC CINE CAMPO AMPLIO                     0
# ID CINE CAMPO ESPECIFICO                   0
# DESC CINE CAMPO ESPECIFICO                 0
# ID CINE CAMPO DETALLADO                    0
# DESC CINE CAMPO DETALLADO                  0
# CÓDIGO DEL DEPARTAMENTO (PROGRAMA)         0
# DEPARTAMENTO DE OFERTA DEL PROGRAMA        0
# CÓDIGO DEL MUNICIPIO (PROGRAMA)            0
# MUNICIPIO DE OFERTA DEL PROGRAMA           0
# ID SEXO                                    0
# SEXO                                       0
# AÑO                                        0
# SEMESTRE                                   0
# MATRICULADOS                               0
# dtype: int64

# %%
#Eliminar columnas innecesarias
columna = ['CÓDIGO DE LA INSTITUCIÓN','IES PADRE', 'ID SECTOR IES','ID CARÁCTER IES','CÓDIGO DEL DEPARTAMENTO (IES)','CÓDIGO DEL MUNICIPIO IES','CÓDIGO SNIES DEL PROGRAMA',
           'ID NIVEL ACADÉMICO','ID NIVEL DE FORMACIÓN','ID MODALIDAD','ID ÁREA','ID NÚCLEO','ID CINE CAMPO AMPLIO','ID CINE CAMPO ESPECIFICO','ID CINE CAMPO DETALLADO',
           'CÓDIGO DEL DEPARTAMENTO (PROGRAMA)','CÓDIGO DEL MUNICIPIO (PROGRAMA)','ID SEXO'
          ]
df = df.drop(columns=columna)

# %%
df.columns
# Out:
# Index(['INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)', 'TIPO IES', 'SECTOR IES',
#        'CARÁCTER IES', 'DEPARTAMENTO DE DOMICILIO DE LA IES',
#        'MUNICIPIO DE DOMICILIO DE LA IES', 'IES ACREDITADA',
#        'PROGRAMA ACADÉMICO', 'PROGRAMA ACREDITADO', 'NIVEL ACADÉMICO',
#        'NIVEL DE FORMACIÓN', 'MODALIDAD', 'ÁREA DE CONOCIMIENTO',
#        'NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)', 'DESC CINE CAMPO AMPLIO',
#        'DESC CINE CAMPO ESPECIFICO', 'DESC CINE CAMPO DETALLADO',
#        'DEPARTAMENTO DE OFERTA DEL PROGRAMA',
#        'MUNICIPIO DE OFERTA DEL PROGRAMA', 'SEXO', 'AÑO', 'SEMESTRE',
#        'MATRICULADOS'],
#       dtype='object')

# %%
df.shape
# Out:
# (75175, 23)

# %%
df.columns = df.columns.str.replace(" ", "_").str.title()
df.columns
# Out:
# Index(['Institución_De_Educación_Superior_(Ies)', 'Tipo_Ies', 'Sector_Ies',
#        'Carácter_Ies', 'Departamento_De_Domicilio_De_La_Ies',
#        'Municipio_De_Domicilio_De_La_Ies', 'Ies_Acreditada',
#        'Programa_Académico', 'Programa_Acreditado', 'Nivel_Académico',
#        'Nivel_De_Formación', 'Modalidad', 'Área_De_Conocimiento',
#        'Núcleo_Básico_Del_Conocimiento_(Nbc)', 'Desc_Cine_Campo_Amplio',
#        'Desc_Cine_Campo_Especifico', 'Desc_Cine_Campo_Detallado',
#        'Departamento_De_Oferta_Del_Programa',
#        'Municipio_De_Oferta_Del_Programa', 'Sexo', 'Año', 'Semestre',
#        'Matriculados'],
#       dtype='object')

# %%
df['Institución_De_Educación_Superior_(Ies)'].unique()
# Out:
# array(['UNIVERSIDAD NACIONAL DE COLOMBIA',
#        'UNIVERSIDAD PEDAGOGICA NACIONAL',
#        'UNIVERSIDAD PEDAGOGICA Y TECNOLOGICA DE COLOMBIA - UPTC',
#        'UNIVERSIDAD DEL CAUCA',
#        'UNIVERSIDAD TECNOLOGICA DE PEREIRA - UTP',
#        'UNIVERSIDAD DE CALDAS', 'UNIVERSIDAD DE CORDOBA',
#        'UNIVERSIDAD SURCOLOMBIANA', 'UNIVERSIDAD DE LA AMAZONIA',
#        'UNIVERSIDAD MILITAR-NUEVA GRANADA',
#        'UNIVERSIDAD TECNOLOGICA DEL CHOCO-DIEGO LUIS CORDOBA',
#        'UNIVERSIDAD DE LOS LLANOS', 'UNIVERSIDAD POPULAR DEL CESAR',
#        'UNIVERSIDAD-COLEGIO MAYOR DE CUNDINAMARCA',
#        'UNIVERSIDAD DEL PACIFICO', 'UNIVERSIDAD DE ANTIOQUIA',
#        'UNIVERSIDAD DEL ATLANTICO', 'UNIVERSIDAD DEL VALLE',
#        'UNIVERSIDAD INDUSTRIAL DE SANTANDER', 'UNIVERSIDAD DE CARTAGENA',
#        'UNIVERSIDAD DE NARIÑO', 'UNIVERSIDAD DEL TOLIMA',
#        'UNIVERSIDAD DEL QUINDIO',
#        'UNIVERSIDAD FRANCISCO DE PAULA SANTANDER',
#        'UNIVERSIDAD DE PAMPLONA',
#        'UNIVERSIDAD DEL MAGDALENA - UNIMAGDALENA',
#        'UNIVERSIDAD DE CUNDINAMARCA-UDEC', 'UNIVERSIDAD DE SUCRE',
#        'UNIVERSIDAD DE LA GUAJIRA',
#        'UNIVERSIDAD DISTRITAL-FRANCISCO JOSE DE CALDAS',
#        'PONTIFICIA UNIVERSIDAD JAVERIANA',
#        'UNIVERSIDAD INCCA DE COLOMBIA', 'UNIVERSIDAD SANTO TOMAS',
#        'UNIVERSIDAD EXTERNADO DE COLOMBIA',
#        'FUNDACION UNIVERSIDAD DE BOGOTA - JORGE TADEO LOZANO',
#        'UNIVERSIDAD CENTRAL', 'UNIVERSIDAD PONTIFICIA BOLIVARIANA',
#        'UNIVERSIDAD DE LA SABANA', 'UNIVERSIDAD EAFIT-',
#        'UNIVERSIDAD DEL NORTE',
#        'COLEGIO MAYOR DE NUESTRA SEÑORA DEL ROSARIO',
#        'FUNDACION UNIVERSIDAD DE AMERICA',
#        'UNIVERSIDAD DE SAN BUENAVENTURA',
#        'UNIVERSIDAD CATOLICA DE COLOMBIA', 'UNIVERSIDAD MARIANA',
#        'UNIVERSIDAD DE MANIZALES',
#        'FUNDACION UNIVERSIDAD AUTONOMA DE COLOMBIA -FUAC-',
#        'UNIVERSIDAD CATOLICA DE ORIENTE -UCO',
#        'UNIVERSIDAD SERGIO ARBOLEDA', 'UNIVERSIDAD EL BOSQUE',
#        'UNIVERSIDAD DE BOYACA UNIBOYACA',
#        'UNIVERSIDAD MANUELA BELTRAN-UMB-', 'UNIVERSIDAD LA GRAN COLOMBIA',
#        'UNIVERSIDAD DE LA SALLE',
#        'UNIVERSIDAD AUTONOMA DEL CARIBE- UNIAUTONOMA',
#        'UNIVERSIDAD SANTIAGO DE CALI', 'UNIVERSIDAD LIBRE',
#        'UNIVERSIDAD DE MEDELLIN', 'UNIVERSIDAD DE LOS ANDES',
#        'UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-',
#        'CORPORACION UNIVERSIDAD PILOTO DE COLOMBIA',
#        'UNIVERSIDAD COOPERATIVA DE COLOMBIA',
#        'UNIVERSIDAD AUTONOMA DE BUCARAMANGA-UNAB-',
#        'UNIVERSIDAD METROPOLITANA', 'UNIVERSIDAD AUTONOMA DE MANIZALES',
#        'UNIVERSIDAD ANTONIO NARIÑO', 'UNIVERSIDAD CATOLICA DE MANIZALES',
#        'UNIVERSIDAD ICESI', 'UNIVERSIDAD AUTONOMA DE OCCIDENTE',
#        'UNIVERSIDAD DE IBAGUE', 'UNIVERSIDAD TECNOLOGICA DE BOLIVAR',
#        'CORPORACIÓN UNIVERSIDAD DEL SINU - ELIAS BECHARA ZAINUM - UNISINU -',
#        'UNIVERSIDAD DE CIENCIAS APLICADAS Y AMBIENTALES - UDCA',
#        'UNIVERSIDAD NACIONAL ABIERTA Y A DISTANCIA UNAD',
#        'ESCUELA SUPERIOR DE ADMINISTRACION PUBLICA-ESAP-',
#        'DIRECCION DE EDUCACION POLICIAL', 'COLEGIO MAYOR DE ANTIOQUIA',
#        'ESCUELA NACIONAL DEL DEPORTE',
#        'INSTITUTO DEPARTAMENTAL DE BELLAS ARTES',
#        'INSTITUTO UNIVERSITARIO DE LA PAZ', 'CONSERVATORIO DEL TOLIMA',
#        'POLITECNICO COLOMBIANO JAIME ISAZA CADAVID',
#        'INSTITUCION UNIVERSITARIA BELLAS ARTES Y CIENCIAS DE BOLIVAR',
#        'UNIDAD CENTRAL DEL VALLE DEL CAUCA',
#        'INSTITUCION UNIVERSITARIA DE ENVIGADO',
#        'INSTITUCION UNIVERSITARIA COLEGIOS DE COLOMBIA - UNICOC',
#        'FUNDACION UNIVERSITARIA DE CIENCIAS DE LA SALUD',
#        'COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACION-CESA-',
#        'FUNDACIÓN UNIVERSITARIA JUAN N. CORPAS', 'UNIVERSIDAD CES',
#        'FUNDACION UNIVERSITARIA SAN MARTIN',
#        'FUNDACION UNIVERSITARIA MONSERRATE -UNIMONSERRATE',
#        'UNIVERSIDAD CATOLICA DE PEREIRA',
#        'FUNDACION UNIVERSITARIA KONRAD LORENZ',
#        'FUNDACION UNIVERSITARIA LOS LIBERTADORES',
#        'FUNDACION UNIVERSITARIA DE POPAYAN',
#        'UNIVERSIDAD CATÓLICA LUIS AMIGÓ',
#        'FUNDACION UNIVERSITARIA JUAN DE CASTELLANOS',
#        'FUNDACION UNIVERSITARIA MARIA CANO',
#        'FUNDACION UNIVERSITARIA AGRARIA DE COLOMBIA -UNIAGRARIA-',
#        'FUNDACION UNIVERSITARIA DE SAN GIL - UNISANGIL -',
#        'POLITECNICO GRANCOLOMBIANO', 'FUNDACION UNIVERSITARIA-CEIPA-',
#        'FUNDACION UNIVERSITARIA DEL AREA ANDINA',
#        'FUNDACION ESCUELA COLOMBIANA DE REHABILITACION',
#        'FUNDACION UNIVERSITARIA CATOLICA LUMEN GENTIUM - UNICATÓLICA - CALI',
#        'FUNDACION UNIVERSITARIA CATOLICA DEL NORTE',
#        'FUNDACIÓN UNIVERSITARIA SAN ALFONSO- FUSA-',
#        'FUNDACION UNIVERSITARIA SEMINARIO BIBLICO DE COLOMBIA - FUSBC',
#        'FUNDACION UNIVERSITARIA EMPRESARIAL DE LA CAMARA DE COMERCIO DE BOGOTA- UNIEMPRESARIAL',
#        'FUNDACION DE ESTUDIOS SUPERIORES UNIVERSITARIOS DE URABA ANTONIO ROLDAN BETANCUR',
#        'INSTITUCION UNIVERSITARIA COLOMBO AMERICANA - UNICA',
#        'FUNDACION DE ESTUDIOS SUPERIORES - MONSEÑOR ABRAHAM ESCUDERO MONTOYA  - FUNDES',
#        'UNIVERSIDAD INTERNACIONAL DEL TRÓPICO AMERICANO - UNITRÓPICO',
#        'UNIVERSIDAD CESMAG - UNICESMAG',
#        'FUNDACIÓN UNIVERSITARIA COMPENSAR',
#        'FUNDACION UNIVERSITARIA SANITAS',
#        'INSTITUCIÓN UNIVERSITARIA VISIÓN DE LAS AMÉRICAS',
#        'FUNDACION UNIVERSITARIA SEMINARIO TEOLOGICO BAUTISTA INTERNACIONAL',
#        'INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA',
#        'UNIVERSIDAD SIMON BOLIVAR',
#        'CORPORACION UNIVERSIDAD DE LA COSTA CUC',
#        'UNIVERSIDAD ESCUELA COLOMBIANA DE INGENIERIA JULIO GARAVITO',
#        'UNIVERSIDAD EAN', 'UNIVERSIDAD EIA',
#        'CORPORACION UNIVERSITARIA ADVENTISTA - UNAC',
#        'CORPORACION UNIVERSITARIA DE SANTA ROSA DE CABAL-UNISARC-',
#        'CORPORACION UNIVERSITARIA LASALLISTA',
#        'CORPORACION UNIVERSITARIA DEL CARIBE - CECAR',
#        'CORPORACION UNIVERSITARIA RAFAEL NUÑEZ',
#        'CORPORACION UNIVERSITARIA DEL META - UNIMETA',
#        'CORPORACION UNIVERSITARIA DEL HUILA-CORHUILA-',
#        'CORPORACION UNIVERSITARIA MINUTO DE DIOS -UNIMINUTO-',
#        'CORPORACION UNIVERSITARIA IBEROAMERICANA',
#        'CORPORACION UNIVERSITARIA DE CIENCIA Y DESARROLLO - UNICIENCIA',
#        'UNIVERSIDAD DE SANTANDER - UDES',
#        'CORPORACION UNIVERSITARIA REMINGTON',
#        'UNIVERSITARIA AGUSTINIANA- UNIAGUSTINIANA',
#        'CORPORACION UNIVERSITARIA EMPRESARIAL DE SALAMANCA',
#        'CORPORACION UNIVERSITARIA REPUBLICANA',
#        'CORPORACION COLEGIATURA COLOMBIANA',
#        'CORPORACION UNIVERSITARIA EMPRESARIAL ALEXANDER VON HUMBOLDT - CUE',
#        'CORPORACION UNIVERSITARIA REFORMADA - CUR -',
#        'UNIVERSIDAD DE INVESTIGACION Y DESARROLLO - UDI',
#        'CORPORACION UNIVERSITARIA  UNITEC',
#        'CORPORACION UNIVERSITARIA AUTONOMA DEL CAUCA',
#        'CORPORACION UNIVERSITARIA ANTONIO JOSE DE SUCRE - CORPOSUCRE',
#        'ESCUELA DE INTELIGENCIA Y CONTRAINTELIGENCIA BRIGADIER GENERAL RICARDO CHARRY SOLANO',
#        'ESCUELA DE LOGISTICA',
#        'ESCUELA SUPERIOR DE GUERRA GENERAL RAFAEL REYES PRIETO',
#        'CENTRO DE EDUCACION MILITAR - CEMIL',
#        'ESCUELA DE POSTGRADOS DE LA FAC-EPFAC',
#        'INSTITUTO SUPERIOR DE EDUCACION RURAL-ISER-',
#        'INSTITUCIÓN UNIVERSITARIA MAYOR DE CARTAGENA',
#        'COLEGIO MAYOR DEL CAUCA',
#        'INSTITUCIÓN UNIVERSITARIA PASCUAL BRAVO',
#        'ESCUELA NAVAL DE SUBOFICIALES ARC BARRANQUILLA',
#        'INSTITUTO TECNOLOGICO DEL PUTUMAYO',
#        'INSTITUCIÓN UNIVERSITARIA DE BARRANQUILLA - IUB',
#        'UNIDADES TECNOLOGICAS DE SANTANDER', 'TECNOLOGICO DE ANTIOQUIA',
#        'INSTITUCION UNIVERSITARIA ANTONIO JOSE CAMACHO',
#        'INSTITUTO TECNOLOGICO METROPOLITANO',
#        'TECNOLÓGICO DE ARTES DÉBORA ARANGO INSTITUCIÓN REDEFINIDA',
#        'FUNDACION TECNOLOGICA AUTONOMA DE BOGOTA-FABA-',
#        'INSTITUCION UNIVERSITARIA ESCOLME',
#        'FUNDACION UNIVERSITARIA TECNOLOGICO COMFENALCO - CARTAGENA',
#        'FUNDACION CENTRO COLOMBIANO DE ESTUDIOS PROFESIONALES, -F.C.E.C.E.P.',
#        'FUNDACION UNIVERSITARIA ANTONIO DE AREVALO - UNITECNAR',
#        'FUNDACION UNIVERSITARIA PARA EL DESARROLLO HUMANO - UNINPAHU',
#        'FUNDACION TECNOLOGICA AUTONOMA DEL PACIFICO', 'TECNOLOGICA FITEC',
#        'FUNDACION DE ESTUDIOS SUPERIORES COMFANORTE -F.E.S.C.-',
#        'INSTITUCION UNIVERSITARIA LATINA - UNILATINA',
#        'FUNDACION UNIVERSITARIA ESUMER',
#        'FUNDACION DE EDUCACION SUPERIOR ALBERTO MERANI',
#        'CORPORACION DE ESTUDIOS TECNOLOGICOS DEL NORTE DEL VALLE',
#        'CORPORACION UNIVERSITARIA CENTRO SUPERIOR - UNICUCES',
#        'CORPORACION ESCUELA SUPERIOR DE ADMINISTRACION Y ESTUDIOS TECNOLOGICOS- EAE',
#        'ESCUELA DE TECNOLOGIAS DE ANTIOQUIA -ETA-',
#        'CORPORACION TECNOLOGICA DE BOGOTA - CTB',
#        'INSTITUTO SUPERIOR DE CIENCIAS SOCIALES Y ECONOMICO FAMILIARES-ICSEF-',
#        'CORPORACION DE EDUCACION DEL NORTE DEL TOLIMA - COREDUCACION',
#        'INSTITUCION UNIVERSITARIA MARCO FIDEL SUAREZ - IUMAFIS',
#        'CORPORACION UNIVERSITARIA AUTONOMA DE NARIÑO -AUNAR-',
#        'CORPORACION TECNOLOGICA INDUSTRIAL COLOMBIANA - TEINCO',
#        'CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA -ATEC-',
#        'CORPORACION POLITECNICO DE LA COSTA ATLANTICA',
#        'CORPORACION INTERNACIONAL PARA EL DESARROLLO EDUCATIVO -CIDE-',
#        'CORPORACIÓN TECNOLÓGICA DE EDUCACIÓN SUPERIOR SAPIENZA - CTES',
#        'CORPORACION UNIVERSAL DE INVESTIGACION Y TECNOLOGIA -CORUNIVERSITEC-',
#        'CORPORACION UNIVERSITARIA COMFACAUCA - UNICOMFACAUCA',
#        'CORPORACION TECNOLOGICA CATOLICA DE OCCIDENTE - TECOC -',
#        'ESCUELA DE FORMACION DE INFANTERIA DE MARINA',
#        'ESCUELA  MILITAR DE SUBOFICIALES SARGENTO INOCENCIO CHINCA',
#        'INSTITUTO DE EDUCACION TECNICA PROFESIONAL DE ROLDANILLO',
#        'INSTITUTO NACIONAL DE FORMACION TECNICA PROFESIONAL DE SAN JUAN DEL CESAR',
#        'INSTITUTO NACIONAL DE FORMACION TECNICA PROFESIONAL DE SAN ANDRES Y PROVIDENCIA - INFOTEP',
#        'UNIDAD TÉCNICA PARA EL DESARROLLO PROFESIONAL - UTEDÉ',
#        'ESCUELA TECNOLOGICA INSTITUTO TECNICO CENTRAL',
#        'INSTITUTO TECNICO NACIONAL DE COMERCIO SIMON RODRIGUEZ - INTENALCO',
#        'INSTITUTO TOLIMENSE DE FORMACION TECNICA PROFESIONAL',
#        'INSTITUTO NACIONAL DE FORMACION TECNICA PROFESIONAL - HUMBERTO VELASQUEZ GARCIA',
#        'COLEGIO INTEGRADO NACIONAL ORIENTE DE CALDAS - IES CINOC',
#        'FUNDACION ACADEMIA DE DIBUJO PROFESIONAL',
#        'FUNDACION DE EDUCACION SUPERIOR SAN JOSE -FESSANJOSE-',
#        'INSTITUCION UNIVERSITARIA EAM',
#        'FUNDACIÓN POLITÉCNICO MINUTO DE DIOS - TEC MD',
#        'FUNDACION INTERAMERICANA TECNICA-FIT-',
#        'FUNDACION DE EDUCACION SUPERIOR NUEVA AMERICA',
#        'FUNDACION UNIVERSITARIA HORIZONTE',
#        'FUNDACION UNIVERSITARIA SAN MATEO - SAN MATEO EDUCACION SUPERIOR',
#        'POLITECNICO INTERNACIONAL INSTITUCION DE EDUCACION SUPERIOR',
#        'CORPORACION ACADEMIA SUPERIOR DE ARTES',
#        'CORPORACION POLITECNICO COLOMBO ANDINO',
#        'CORPORACION CENTRO DE ESTUDIOS ARTISTICOS Y TECNICOS-CEART-',
#        'CORPORACION REGIONAL DE EDUCACION SUPERIOR-CRES-DE CALI',
#        'CORPORACION UNIVERSITARIA CENDA',
#        'CORPORACIÓN UNIFICADA HISPANOAMERICANA DE EDUCACIÓN SUPERIOR',
#        'CORPORACION DE EDUCACION SUPERIOR SURAMERICA',
#        'CORPORACION UNIFICADA NACIONAL DE EDUCACION SUPERIOR-CUN-',
#        'CORPORACION DE EDUCACIÓN SUPERIOR DEL LITORAL',
#        'CORPORACION UNIVERSITARIA LATINOAMERICANA - CUL',
#        'CORPORACION ESCUELA DE ARTES Y LETRAS',
#        'CORPORACION INSTITUTO DE ADMINISTRACION Y FINANZAS - CIAF',
#        'CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE -IAFIC-',
#        'CORPORACION INTERAMERICANA DE EDUCACION SUPERIOR-CORPOCIDES',
#        'CORPORACION INSTITUTO SUPERIOR DE EDUCACION SOCIAL-ISES-',
#        'CORPORACION UNIVERSITARIA TALLER CINCO CENTRO DE DISEÑO',
#        'CORPORACION UNIVERSITARIA DE CIENCIAS EMPRESARIALES, EDUCACION Y SALUD -UNICORSALUD-',
#        'CORPORACION ESCUELA TECNOLOGICA DEL ORIENTE', 'UNIVERSIDAD ECCI',
#        'ESCUELA DE SUBOFICIALES DE LA FUERZA AEREA COLOMBIANA ANDRES M. DIAZ',
#        'ESCUELA MILITAR DE AVIACION MARCO FIDEL SUAREZ',
#        'ESCUELA MILITAR DE CADETES GENERAL JOSE MARIA CORDOVA',
#        'ESCUELA NAVAL DE CADETES ALMIRANTE PADILLA',
#        'ESCUELA DE INGENIEROS MILITARES', 'INSTITUTO CARO Y CUERVO',
#        'SERVICIO NACIONAL DE APRENDIZAJE-SENA-',
#        'FUNDACION UNIVERSITARIA CLARETIANA - UNICLARETIANA',
#        'ESCUELA INTERNACIONAL DE ESTUDIOS SUPERIORES - INTER',
#        'CORPORACION UNIVERSITARIA AMERICANA',
#        'FUNDACION UNIVERSITARIA BELLAS ARTES',
#        'FUNDACION UNIVERSITARIA COLOMBO INTERNACIONAL - UNICOLOMBO',
#        'TECNOLOGICO COREDI', 'CORPORACION TECNOLOGICA INDOAMERICA',
#        'CORPORACION UNIVERSITARIA DE SABANETA - UNISABANETA',
#        'LCI - FUNDACION TECNOLOGICA',
#        'FUNDACION UNIVERSITARIA CAFAM -UNICAFAM',
#        'FUNDACIÓN UNIVERSITARIA CERVANTES SAN AGUSTÍN - UNICERVANTES',
#        'FUNDACION UNIVERSITARIA CIEO - UNICIEO',
#        'INSTITUCION UNIVERSITARIA DE COLOMBIA - UNIVERSITARIA DE COLOMBIA',
#        'CORPORACION UNIVERSITARIA U DE COLOMBIA',
#        'FUNDACION UNIVERSITARIA COMFENALCO SANTANDER',
#        'CORPORACIÓN COLSUBSIDIO EDUCACIÓN TECNOLÓGICA - CET',
#        'FUNDACION UNIVERSITARIA COLOMBO GERMANA',
#        'FUNDACION ESCUELA TECNOLOGICA DE NEIVA - JESUS OVIEDO PEREZ -FET',
#        'CORPORACIÓN UNIVERSITARIA PARA EL DESARROLLO EMPRESARIAL Y SOCIAL - MISIÓN PAZ.',
#        'FUNDACION UNIVERSITARIA NAVARRA - UNINAVARRA',
#        'FUNDACION UNIVERSITARIA LUIS G. PAEZ - UNIPAEZ',
#        'CORPORACION UNIVERSITARIA DE ASTURIAS',
#        'ESEIT - ESCUELA SUPERIOR DE EMPRESA, INGENIERÍA Y TECNOLOGÍA',
#        'UNIVERSITARIA VIRTUAL INTERNACIONAL',
#        'FUNDACION UNIVERSITARIA CATOLICA DEL SUR - UNICATOLICA DEL SUR',
#        'FUNDACION UNIVERSITARIA COMFAMILIAR RISARALDA',
#        'CORPORACION UNIVERSITARIA DE CATALUÑA',
#        'FUNDACION UNIVERSITARIA INTERNACIONAL DE COLOMBIA - UNINCOL',
#        'FUNDACION UNIVERSITARIA INTERNACIONAL DE LA RIOJA - UNIR',
#        'INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA -IU. DIGITAL',
#        'FUNDACIÓN UNIVERSITARIA SALESIANA',
#        'UNIVERSIDAD AUTÓNOMA INDÍGENA INTERCULTURAL - UAIIN',
#        'INSTITUCIÓN UNIVERSITARIA COMANDO DE EDUCACIÓN Y DOCTRINA - CEDOC DEL EJÉRCITO NACIONAL',
#        'FUNDACIÓN UNIVERSITARIA PATRICIO SYMES',
#        'FUNDACIÓN UNIVERSITARIA SAN PABLO - UNISANPABLO',
#        'UNIDAD TECNOLÓGICA DEL MAGDALENA MEDIO - UTEM -',
#        'CORPORACIÓN UNIVERSITARIA AUTÓNOMA DEL NORTE',
#        'UNIVERSITARIA DEL CHICAMOCHA'], dtype=object)

# %%
df['Departamento_De_Oferta_Del_Programa'].unique()
# Out:
# array(['Bogotá, D.C.', 'Antioquia', 'Caldas', 'Valle del Cauca', 'Boyacá',
#        'Casanare', 'Cauca', 'Nariño', 'Risaralda', 'La Guajira', 'Huila',
#        'Córdoba', 'Caquetá', 'Guaviare', 'Amazonas', 'Cundinamarca',
#        'Bolívar', 'Chocó', 'Meta', 'Cesar',
#        'Archipiélago de San Andrés, Providencia y Santa Catalina',
#        'Quindío', 'Atlántico', 'Santander', 'Tolima', 'Putumayo',
#        'Norte de Santander', 'Vaupés', 'Magdalena', 'Sucre', 'Arauca',
#        'Vichada', 'Guainía'], dtype=object)

# %%
df['Programa_Académico'].unique()
# Out:
# array(['INGENIERIA AGRONOMICA', 'NUTRICION Y DIETETICA',
#        'MAESTRIA EN INGENIERIA - GEOTECNIA', ...,
#        'TECNOLOGIA EN GESTION TRIBUTARIA, CONTABLE Y FINANCIERA',
#        'COMUNICACIÓN SOCIAL Y MEDIOS', 'Gastronomía y Artes Culinarias'],
#       dtype=object)

# %%
df['Modalidad'].unique()
# Out:
# array(['Presencial', 'A distancia', 'Presencial-Virtual', 'Virtual',
#        'Híbrida (Presencial-Virtual)', 'Dual', 'Virtual-Dual',
#        'Presencial-A distancia', 'Virtual-A distancia', 'Presencial-Dual'],
#       dtype=object)

# %%
df.loc[df['Departamento_De_Oferta_Del_Programa']== 'Antioquia', ['Institución_De_Educación_Superior_(Ies)','Programa_Académico','Modalidad']]
# Out:
#                  Institución_De_Educación_Superior_(Ies)  \
# 1023                    UNIVERSIDAD NACIONAL DE COLOMBIA
# 1024                    UNIVERSIDAD NACIONAL DE COLOMBIA
# 1025                    UNIVERSIDAD NACIONAL DE COLOMBIA
# 1026                    UNIVERSIDAD NACIONAL DE COLOMBIA
# 1027                    UNIVERSIDAD NACIONAL DE COLOMBIA
# ...                                                  ...
# 74477  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...
# 74478  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...
# 74773  UNIVERSIDAD AUTÓNOMA INDÍGENA INTERCULTURAL - ...
# 74774  UNIVERSIDAD AUTÓNOMA INDÍGENA INTERCULTURAL - ...
# 74775  UNIVERSIDAD AUTÓNOMA INDÍGENA INTERCULTURAL - ...
#
#                                       Programa_Académico   Modalidad
# 1023       MAESTRIA EN INGENIERIA - INGENIERIA ELECTRICA  Presencial
# 1024       MAESTRIA EN INGENIERIA - INGENIERIA ELECTRICA  Presencial
# 1025       MAESTRIA EN INGENIERIA - INGENIERIA ELECTRICA  Presencial
# 1026       MAESTRIA EN INGENIERIA - INGENIERIA ELECTRICA  Presencial
# 1027                      MAESTRÍA EN ESTUDIOS POLÍTICOS  Presencial
# ...                                                  ...         ...
# 74477  Tecnología en Gestión Logística Portuaria y de...     Virtual
# 74478  Tecnología en Gestión Logística Portuaria y de...     Virtual
# 74773                       DERECHO PROPIO INTERCULTURAL  Presencial
# 74774                       DERECHO PROPIO INTERCULTURAL  Presencial
# 74775                       DERECHO PROPIO INTERCULTURAL  Presencial
#
# [9422 rows x 3 columns]
